# %%
# %matplotlib inline

# %%
import sys, os
sys.path.insert(0, os.path.abspath('bin'))
import tool4nanobio
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ac1f4d5ed965> in <module>()
#       1 import sys, os
#       2 sys.path.insert(0, os.path.abspath('bin'))
# ----> 3 import tool4nanobio
#
# ~/git/tool4nanobio/bin/tool4nanobio.py in <module>()
#      37 full_xml_filename = os.path.abspath(xml_file)
#      38
# ---> 39 tree = ET.parse(full_xml_filename)  # this file cannot be overwritten; part of tool distro
#      40 xml_root = tree.getroot()
#      41 user_tab = UserTab()
#
# ~/anaconda3/lib/python3.6/xml/etree/ElementTree.py in parse(source, parser)
#    1194     """
#    1195     tree = ElementTree()
# -> 1196     tree.parse(source, parser)
#    1197     return tree
#    1198
#
# ~/anaconda3/lib/python3.6/xml/etree/ElementTree.py in parse(self, source, parser)
#     584         close_source = False
#     585         if not hasattr(source, "read"):
# ...

# %%
tool4nanobio.gui

# %%
#from debug import debug_view
#debug_view
